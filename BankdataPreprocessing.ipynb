# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-54a3b14d-e07e-46c9-9357-e30aa19dd8e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-54a3b14d-e07e-46c9-9357-e30aa19dd8e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Banking Data.csv to Banking Data (1).csv

# %%
import pandas as pd
df = pd.read_csv("Banking Data.csv") 
df
# Out:
#       RowNumber  CustomerId    Surname  ...  IsActiveMember EstimatedSalary Exited
# 0           1.0  15634602.0   Hargrave  ...             1.0       101348.88    1.0
# 1           2.0  15647311.0       Hill  ...             1.0       112542.58    0.0
# 2           3.0  15619304.0       Onio  ...             0.0       113931.57    1.0
# 3           4.0  15701354.0       Boni  ...             0.0        93826.63    0.0
# 4           5.0  15737888.0   Mitchell  ...             1.0        79084.10    0.0
# ...         ...         ...        ...  ...             ...             ...    ...
# 9995     9996.0  15606229.0   Obijiaku  ...             0.0        96270.64    0.0
# 9996     9997.0  15569892.0  Johnstone  ...             1.0       101699.77    0.0
# 9997     9998.0  15584532.0        Liu  ...             1.0        42085.58    1.0
# 9998     9999.0  15682355.0  Sabbatini  ...             0.0        92888.52    1.0
# ...

# %%
data = df.copy()
data
# Out:
#       RowNumber  CustomerId    Surname  ...  IsActiveMember EstimatedSalary Exited
# 0           1.0  15634602.0   Hargrave  ...             1.0       101348.88    1.0
# 1           2.0  15647311.0       Hill  ...             1.0       112542.58    0.0
# 2           3.0  15619304.0       Onio  ...             0.0       113931.57    1.0
# 3           4.0  15701354.0       Boni  ...             0.0        93826.63    0.0
# 4           5.0  15737888.0   Mitchell  ...             1.0        79084.10    0.0
# ...         ...         ...        ...  ...             ...             ...    ...
# 9995     9996.0  15606229.0   Obijiaku  ...             0.0        96270.64    0.0
# 9996     9997.0  15569892.0  Johnstone  ...             1.0       101699.77    0.0
# 9997     9998.0  15584532.0        Liu  ...             1.0        42085.58    1.0
# 9998     9999.0  15682355.0  Sabbatini  ...             0.0        92888.52    1.0
# ...

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        9995 non-null   float64
#  1   CustomerId       9991 non-null   float64
#  2   Surname          9991 non-null   object
#  3   CreditScore      9994 non-null   float64
#  4   Geography        9992 non-null   object
#  5   Gender           9982 non-null   object
#  6   Age              9994 non-null   float64
#  7   Tenure           9995 non-null   float64
#  8   Balance          9985 non-null   float64
#  9   NumOfProducts    9983 non-null   float64
#  10  HasCrCard        9985 non-null   float64
#  11  IsActiveMember   9995 non-null   float64
#  12  EstimatedSalary  9988 non-null   float64
#  13  Exited           9995 non-null   float64
# dtypes: float64(11), object(3)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#           RowNumber    CustomerId  ...  EstimatedSalary       Exited
# count   9995.000000  9.991000e+03  ...      9988.000000  9995.000000
# mean    5002.809405  1.569096e+07  ...    100105.925692     0.203802
# std     2885.769998  7.193458e+04  ...     57510.454893     0.402844
# min        1.000000  1.556570e+07  ...        11.580000     0.000000
# 25%     2504.500000  1.562854e+07  ...     51078.675000     0.000000
# 50%     5003.000000  1.569074e+07  ...    100193.915000     0.000000
# 75%     7501.500000  1.575329e+07  ...    149401.645000     0.000000
# max    10000.000000  1.581569e+07  ...    199992.480000     1.000000
#
# [8 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# RowNumber           5
# CustomerId          9
# Surname             9
# CreditScore         6
# Geography           8
# Gender             18
# Age                 6
# Tenure              5
# Balance            15
# NumOfProducts      17
# HasCrCard          15
# IsActiveMember      5
# EstimatedSalary    12
# Exited              5
# dtype: int64

# %%
data["Gender"].fillna('No Gender', inplace = True)
data["Geography"].fillna('No Geography', inplace = True)

# %%
#Trasnforming text features into Numeric categorical variables
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
data['Gender'] = le.fit_transform(data['Gender'])
data['Geography'] = le.fit_transform(data['Geography'])

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  ...  IsActiveMember  EstimatedSalary  Exited
# 0           1.0  15634602.0   Hargrave  ...             1.0        101348.88     1.0
# 1           2.0  15647311.0       Hill  ...             1.0        112542.58     0.0
# 2           3.0  15619304.0       Onio  ...             0.0        113931.57     1.0
# 3           4.0  15701354.0       Boni  ...             0.0         93826.63     0.0
# 4           5.0  15737888.0   Mitchell  ...             1.0         79084.10     0.0
# ...         ...         ...        ...  ...             ...              ...     ...
# 9995     9996.0  15606229.0   Obijiaku  ...             0.0         96270.64     0.0
# 9996     9997.0  15569892.0  Johnstone  ...             1.0        101699.77     0.0
# 9997     9998.0  15584532.0        Liu  ...             1.0         42085.58     1.0
# 9998     9999.0  15682355.0  Sabbatini  ...             0.0         92888.52     1.0
# ...

# %%
data[pd.isnull(data).any(axis=1)]
# Out:
#      RowNumber  CustomerId  ... EstimatedSalary  Exited
# 154      155.0  15709368.0  ...       109041.53     0.0
# 155      156.0  15679145.0  ...        17941.16     1.0
# 156      157.0  15655007.0  ...        82996.47     0.0
# 157      158.0  15623595.0  ...        92067.35     0.0
# 303      304.0  15624188.0  ...       190686.16     0.0
# 304      305.0  15812191.0  ...        94440.45     0.0
# 305      306.0  15636673.0  ...        28257.63     0.0
# 306      307.0  15594898.0  ...       170034.95     1.0
# 307      308.0  15660211.0  ...        31824.29     0.0
# 343      344.0  15684484.0  ...       127587.22     0.0
# 381        NaN         NaN  ...             NaN     NaN
# 382        NaN         NaN  ...             NaN     NaN
# 383        NaN         NaN  ...             NaN     NaN
# 384        NaN         NaN  ...             NaN     NaN
# 385        NaN         NaN  ...             NaN     NaN
# 439      440.0         NaN  ...       164104.74     0.0
# ...

# %%
data = data[data.isnull().sum(axis=1) < 10]

# %%
data[pd.isnull(data).any(axis=1)]
# Out:
#      RowNumber  CustomerId  ... EstimatedSalary  Exited
# 154      155.0  15709368.0  ...       109041.53     0.0
# 155      156.0  15679145.0  ...        17941.16     1.0
# 156      157.0  15655007.0  ...        82996.47     0.0
# 157      158.0  15623595.0  ...        92067.35     0.0
# 303      304.0  15624188.0  ...       190686.16     0.0
# 304      305.0  15812191.0  ...        94440.45     0.0
# 305      306.0  15636673.0  ...        28257.63     0.0
# 306      307.0  15594898.0  ...       170034.95     1.0
# 307      308.0  15660211.0  ...        31824.29     0.0
# 343      344.0  15684484.0  ...       127587.22     0.0
# 439      440.0         NaN  ...       164104.74     0.0
# 456      457.0         NaN  ...         7666.73     0.0
# 457      458.0         NaN  ...        68487.51     0.0
# 561      562.0         NaN  ...        82970.69     0.0
# 593      594.0  15775153.0  ...             NaN     0.0
# 594      595.0  15603925.0  ...             NaN     0.0
# ...

# %%
data["Age"].fillna(round(data["Age"].mean(),2), inplace = True)
data["Balance"].fillna(round(data["Balance"].mean(),2), inplace = True)
data["NumOfProducts"].fillna(data["NumOfProducts"].mode()[0], inplace = True)
data["CreditScore"].fillna(int(data["CreditScore"].mean()), inplace = True)
data["HasCrCard"].fillna(2, inplace = True)
data["CustomerId"].fillna(0, inplace = True)
data["EstimatedSalary"].fillna(round(data["EstimatedSalary"].mean(),2), inplace = True)
data = data.drop(['Surname'], axis = 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
data.isnull().values.any()
# Out:
# False

# %%
dupval = data.duplicated()
print(dupval.sum())
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
sns.barplot(x='Exited',y='Age',data=data)

# %%
sns.heatmap(data.corr(),cmap = "RdYlGn")

# %%
sns.barplot(x='IsActiveMember',y='Age',data=data)

# %%
sns.barplot(x='NumOfProducts',y='Balance',data=data)

# %%
sns.regplot(x='CreditScore',y='Balance',data=data)

# %%
sns.regplot(x='EstimatedSalary',y='Balance',data=data)
